# %%
import pandas as pd
import numpy as np
ds=pd.read_csv('Market_Basket_Optimisation.csv')
ds
# Out:
#               shrimp            almonds      avocado    vegetables mix
# 0            burgers          meatballs         eggs               NaN  \
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink
# ...

# %%
records =[]
for i in range(0,10):
    records.append([str(ds.values[i,j]) for j in range(2,8)])

# %%
pip install apyori
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from apyori import apriori

# %%
as_rules = apriori(records , min_support = 0.003 ,min_confidence = 0.2 ,min_lift=1.5 , min_length=2)
as_results =list(as_rules)

# %%
print(len(as_results))
# Out:
# 8

# %%
print(as_results)
# Out:
# [RelationRecord(items=frozenset({'green tea', 'energy bar'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy bar'}), items_add=frozenset({'green tea'}), confidence=1.0, lift=5.0), OrderedStatistic(items_base=frozenset({'green tea'}), items_add=frozenset({'energy bar'}), confidence=0.5, lift=5.0)]), RelationRecord(items=frozenset({'whole wheat rice', 'energy bar'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'energy bar'}), items_add=frozenset({'whole wheat rice'}), confidence=1.0, lift=10.0), OrderedStatistic(items_base=frozenset({'whole wheat rice'}), items_add=frozenset({'energy bar'}), confidence=1.0, lift=10.0)]), RelationRecord(items=frozenset({'whole wheat rice', 'green tea'}), support=0.1, ordered_statistics=[OrderedStatistic(items_base=frozenset({'green tea'}), items_add=frozenset({'whole wheat rice'}), confidence=0.5, lift=5.0), OrderedStatistic(items_base=frozenset({'whole wheat rice'}), items_add=frozenset({'gre
# ...
